# %% [markdown]
# <a href="https://colab.research.google.com/github/Archnajha10/python-code/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime

# %%
import math as m
m.sqrt(2)
# Out:
# 1.4142135623730951

# %%
m.pow(2,8)
# Out:
# 256.0

# %%
m.factorial(5)
# Out:
# 120

# %%
import random as r

# %%
r.random()
# Out:
# 0.1790479415162487

# %%
r.randint(1000,9999)
# Out:
# 4787

# %%
ls2 = ["a","b","c","d","e"]
r.shuffle(ls2)

# %%
ls2
# Out:
# ['c', 'd', 'b', 'a', 'e']
