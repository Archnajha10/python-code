# %% [markdown]
# <a href="https://colab.research.google.com/github/Archnajha10/python-code/blob/main/untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime

# %%
from datetime import date,time,datetime,timedelta

# %%
curr_datetime = datetime.now()

# %%
curr_datetime
# Out:
# datetime.datetime(2026, 1, 3, 9, 37, 14, 864421)

# %%
curr_datetime.year
# Out:
# 2026

# %%
curr_datetime.month
# Out:
# 1

# %%
curr_datetime.day
# Out:
# 3
